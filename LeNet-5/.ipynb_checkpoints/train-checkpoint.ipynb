# %%
import tensorflow as tf
from tensorflow.keras import layers,losses,optimizers
from tensorflow.keras.callbacks import Callback,TensorBoard
import pickle
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt

# %%
'''
class LossAndErrorPrintingCallback(Callback):
    def __init__(self, ):
        self.loss_arr = []
    def on_train_batch_end(self, batch, logs=None):
        print('For batch {}, loss is {:7.2f}.'.format(batch, logs['loss']))
        self.loss_arr.append(logs['loss'])
    def on_epoch_end(self, epoch, logs=None):
        x = [i for i in range(0,len(self.loss_arr))]
        y = self.loss_arr
        plt.plot(x, y)
        plt.xlabel('iteration')
        plt.ylabel('loss')
        plt.show()
'''
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
    return dict

def randomShowPics():
    info = unpickle('dataset/batches.meta')
    label_names = info['label_names']
    data = unpickle('dataset/data_batch_1')
    imgs = data['data'].reshape(-1,3,32,32)
    labels = data['labels']
    imgs = np.transpose(imgs, (0, 2, 3,1))
    for i in range(10):
        idx = random.randint(0,9999)
        img = imgs[idx]
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        cv2.namedWindow(label_names[labels[idx]],0);
        cv2.resizeWindow(label_names[labels[idx]], 300, 300);
        cv2.imshow(label_names[labels[idx]],img)
        cv2.waitKey(1000)
        cv2.destroyAllWindows()
        
def loadDataset():
    data = unpickle('dataset/data_batch_1')
    X_train = data['data'].reshape(-1,3,32,32)
    Y_train = np.array(data['labels']).reshape(-1,1)
    for i in range(2,6):
        data = unpickle('dataset/data_batch_'+str(i))
        X = data['data'].reshape(-1,3,32,32)
        Y = np.array(data['labels']).reshape(-1,1)
        X_train = np.concatenate((X_train,X), axis=0)
        Y_train = np.concatenate((Y_train,Y), axis=0)
    X_train = np.transpose(X_train, (0, 2, 3, 1)) 
    
    data_test = unpickle('dataset/test_batch')
    X_test = data_test['data'].reshape(-1,3,32,32)
    X_test = np.transpose(X_test, (0, 2, 3, 1)) 
    Y_test = np.array(data_test['labels']).reshape(-1,1)
    return X_train, Y_train, X_test, Y_test

def printHyperparameter():
    print('hyperparameters:\n')
def createLeNetModel():
    #kernel_initializer='glorot_normal'
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(filters=6, kernel_size=(5, 5),strides=(1, 1), padding='valid',activation='relu', input_shape=(32,32,3)))
    model.add(layers.AveragePooling2D(pool_size=(2, 2),padding='valid'))
    model.add(layers.Conv2D(filters=16, kernel_size=(5, 5),strides=(1, 1), padding='valid',activation='relu'))
    model.add(layers.AveragePooling2D(pool_size=(2, 2),padding='valid'))
    model.add(layers.Flatten())
    model.add(layers.Dense(120,activation='relu'))
    model.add(layers.Dense(84,activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(10,activation='softmax'))
    #sgd = tf.keras.optimizers.SGD(lr=0.1, decay=1e-3, momentum=0.9, nesterov=True)
    model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    #model.compile(optimizer=sgd,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    
    return model
'''
def train_one_epoch(X_train,Y_train,X_test,Y_test):
    model = createLeNetModel()
    history = model.fit(X_train[0:1000], Y_train[0:1000], epochs=1,batch_size=32,callbacks=[BaseLogger()])
    #loss, acc = model.evaluate(x=X_test, y=Y_test)
    #print("loss: %s, acc: %s" % (loss, acc))
'''
    
def train(X_train, Y_train, X_test, Y_test):
    checkpoint_dir = "model/"
    checkpoint_path = checkpoint_dir + "cp-{epoch:04d}.ckpt"
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model = createLeNetModel()
    model.summary()
    if latest:
        print('Train from '+latest)
        model.load_weights(latest)
    epoch = 400
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,save_weights_only=True,verbose=1,period=20)
    history = model.fit(X_train, Y_train, epochs=epoch,batch_size=256,callbacks=[],verbose=1)
    loss, acc = model.evaluate(x=X_test, y=Y_test,batch_size=256, verbose=0)
    
    # list all data in history
    print(history.history.keys())
    print(history.history['accuracy'])
    # summarize history for accuracy
    plt.figure(num='Predict',figsize=(12, 10))
    plt.subplot(2,1,1)
    plt.plot([x for x in range(1,epoch+1)],history.history['accuracy'])
    plt.title('Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    #plt.legend(['train'], loc='upper left')
    # summarize history for loss
    plt.subplot(2,1,2)
    plt.plot([x for x in range(1,epoch+1)],history.history['loss'])
    plt.title('Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    #plt.legend(['train'], loc='upper left')
    plt.show()

    print("test loss: %s, acc: %s" % (loss, acc))

def predict(index):
    info = unpickle('dataset/batches.meta')
    label_names = info['label_names']
    X_train, Y_train, X_test, Y_test = loadDataset()
    X = np.array([X_test[index]], dtype="float32")
    checkpoint_dir = "model/"
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model = createLeNetModel()
    if latest:
        model.load_weights(latest)
    predict = model.predict(X)
    plt.bar(label_names,predict[0])
    prob = predict[0].tolist()
    idx = prob.index(max(prob))
    cv2.namedWindow(label_names[idx],0);
    cv2.resizeWindow(label_names[idx], 300, 300);
    cv2.imshow(label_names[idx],X_test[index])
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
X_train, Y_train, X_test, Y_test = loadDataset()
train(X_train, Y_train, X_test, Y_test)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 28, 28, 6)         456
# _________________________________________________________________
# average_pooling2d_16 (Averag (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_17 (Averag (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 120)               48120
# _________________________________________________________________
# dense_25 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 84)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                850
# =================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Train on 50000 samples
# Epoch 1/400
# 50000/50000 [==============================] - 13s 257us/sample - loss: 2.0893 - accuracy: 0.2400
# Epoch 2/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 1.6602 - accuracy: 0.3918
# Epoch 3/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 1.4915 - accuracy: 0.4618
# Epoch 4/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 1.3870 - accuracy: 0.5038
# Epoch 5/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 1.3047 - accuracy: 0.5367
# Epoch 6/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 1.2408 - accuracy: 0.5589
# Epoch 7/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 1.1855 - accuracy: 0.5789
# Epoch 8/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 1.1388 - accuracy: 0.5973
# Epoch 9/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 1.0953 - accuracy: 0.6123
# Epoch 10/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 1.0721 - accuracy: 0.6197
# Epoch 11/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 1.0208 - accuracy: 0.6389
# Epoch 12/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.9830 - accuracy: 0.6512
# Epoch 13/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.9515 - accuracy: 0.6597
# Epoch 14/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.9270 - accuracy: 0.6709
# Epoch 15/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.8968 - accuracy: 0.6812
# Epoch 16/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.8706 - accuracy: 0.6883
# Epoch 17/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0
400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3587 - accuracy: 0.8642
# Epoch 80/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3443 - accuracy: 0.8708
# Epoch 81/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3535 - accuracy: 0.8671
# Epoch 82/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3586 - accuracy: 0.8647
# Epoch 83/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3639 - accuracy: 0.8642
# Epoch 84/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3418 - accuracy: 0.8714
# Epoch 85/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3543 - accuracy: 0.8662
# Epoch 86/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3486 - accuracy: 0.8685
# Epoch 87/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3406 - accuracy: 0.8725
# Epoch 88/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3436 - accuracy: 0.8712
# Epoch 89/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3395 - accuracy: 0.8730
# Epoch 90/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3348 - accuracy: 0.8741
# Epoch 91/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3280 - accuracy: 0.8775
# Epoch 92/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3386 - accuracy: 0.8721
# Epoch 93/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3473 - accuracy: 0.8684
# Epoch 94/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3389 - accuracy: 0.8721
# Epoch 95/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3352 - accuracy: 0.8748
# Epoch 96/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3308 - accuracy: 0.8756
# Epoch 97/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3063 - accuracy: 0.8845
# Epoch 98/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3295 - accuracy: 0.8774
# Epoch 99/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3145 - accuracy: 0.8818
# Epoch 100/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3107 - accuracy: 0.8843
# Epoch 101/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3205 - accuracy: 0.8793
# Epoch 102/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3224 - accuracy: 0.8775
# Epoch 103/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3163 - accuracy: 0.8805
# Epoch 104/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3276 - accuracy: 0.8762
# Epoch 105/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3131 - accuracy: 0.8821
# Epoch 106/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3195 - accuracy: 0.8799
# Epoch 107/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3226 - accuracy: 0.8801
# Epoch 108/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3001 - accuracy: 0.8868
# Epoch 109/400
# 50000/50000 [==============================] - 13s 256us/sample - loss: 0.2937 - accuracy: 0.8897
# Epoch 110/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3156 - accuracy: 0.8817
# Epoch 111/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3077 - accuracy: 0.8835
# Epoch 112/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.3082 - accuracy: 0.8841
# Epoch 113/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3028 - accuracy: 0.8842
# Epoch 114/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3033 - accuracy: 0.8850
# Epoch 115/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3070 - accuracy: 0.8864
# Epoch 116/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3393 - accuracy: 0.8739
# Epoch 117/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2956 - accuracy: 0.8890
# Epoch 118/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3091 - accuracy: 0.8860
# Epoch 119/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2971 - accuracy: 0.8881
# Epoch 120/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2876 - accuracy: 0.8918
# Epoch 121/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3063 - accuracy: 0.8853
# Epoch 122/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.3058 - accuracy: 0.8858
# Epoch 123/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2885 - accuracy: 0.8919
# Epoch 124/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2832 - accuracy: 0.8942
# Epoch 125/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2767 - accuracy: 0.8964
# Epoch 126/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2799 - accuracy: 0.8956
# Epoch 127/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2883 - accuracy: 0.8904
# Epoch 128/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2967 - accuracy: 0.8880
# Epoch 129/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2902 - accuracy: 0.8913
# Epoch 130/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2810 - accuracy: 0.8959
# Epoch 131/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2827 - accuracy: 0.8936
# Epoch 132/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2755 - accuracy: 0.8976
# Epoch 133/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2822 - accuracy: 0.8946
# Epoch 134/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2730 - accuracy: 0.8989
# Epoch 135/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2820 - accuracy: 0.8953
# Epoch 136/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2734 - accuracy: 0.8983
# Epoch 137/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2953 - accuracy: 0.8905
# Epoch 138/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2779 - accuracy: 0.8958
# Epoch 139/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2700 - accuracy: 0.8973
# Epoch 140/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2757 - accuracy: 0.8977
# Epoch 141/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2862 - accuracy: 0.8916
# Epoch 142/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2636 - accuracy: 0.9029
# Epoch 143/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2750 - accuracy: 0.8979
# Epoch 144/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2917 - accuracy: 0.8920
# Epoch 145/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2698 - accuracy: 0.8988
# Epoch 146/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2661 - accuracy: 0.9002
# Epoch 147/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2572 - accuracy: 0.9028
# Epoch 148/400
# 50000/50000 [==============================] - 13s 256us/sample - loss: 0.2788 - accuracy: 0.8970
# Epoch 149/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2656 - accuracy: 0.8997
# Epoch 150/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2686 - accuracy: 0.8995
# Epoch 151/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2673 - accuracy: 0.9005
# Epoch 152/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2749 - accuracy: 0.8972
# Epoch 153/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2573 - accuracy: 0.9050
# Epoch 154/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2579 - accuracy: 0.9022
# Epoch 155/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2615 - accuracy: 0.9018
# Epoch 156/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2724 - accuracy: 0.8988
# Epoch 157/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2550 - accuracy: 0.9048
# Epoch 158/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2611 - accuracy: 0.9017
# Epoch 159/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2749 - accuracy: 0.8990
# Epoch 160/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2649 - accuracy: 0.9012
# Epoch 161/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2653 - accuracy: 0.9014
# Epoch 162/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2675 - accuracy: 0.9005
# Epoch 163/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2539 - accuracy: 0.9062
# Epoch 164/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2681 - accuracy: 0.9015
# Epoch 165/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2527 - accuracy: 0.9072
# Epoch 166/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2413 - accuracy: 0.9105
# Epoch 167/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2817 - accuracy: 0.8952
# Epoch 168/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2577 - accuracy: 0.9048
# Epoch 169/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2408 - accuracy: 0.9100
# Epoch 170/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2592 - accuracy: 0.9031
# Epoch 171/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2636 - accuracy: 0.9030
# Epoch 172/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2424 - accuracy: 0.9094
# Epoch 173/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2341 - accuracy: 0.9130
# Epoch 174/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2514 - accuracy: 0.9069
# Epoch 175/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2519 - accuracy: 0.9063
# Epoch 176/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2486 - accuracy: 0.9078
# Epoch 177/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2469 - accuracy: 0.9073
# Epoch 178/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2496 - accuracy: 0.9082
# Epoch 179/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2406 - accuracy: 0.9111
# Epoch 180/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2485 - accuracy: 0.9069
# Epoch 181/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2530 - accuracy: 0.9066
# Epoch 182/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2471 - accuracy: 0.9076
# Epoch 183/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2503 - accuracy: 0.9069
# Epoch 184/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2537 - accuracy: 0.9057
# Epoch 185/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2366 - accuracy: 0.9123
# Epoch 186/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2394 - accuracy: 0.9115
# Epoch 187/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2434 - accuracy: 0.9083
# Epoch 188/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2468 - accuracy: 0.9089
# Epoch 189/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2519 - accuracy: 0.9068
# Epoch 190/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2410 - accuracy: 0.9109
# Epoch 191/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2287 - accuracy: 0.9152
# Epoch 192/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2486 - accuracy: 0.9064
# Epoch 193/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2391 - accuracy: 0.9113
# Epoch 194/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2323 - accuracy: 0.9140
# Epoch 195/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2236 - accuracy: 0.9176
# Epoch 196/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2459 - accuracy: 0.9097
# Epoch 197/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2424 - accuracy: 0.9106
# Epoch 198/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2369 - accuracy: 0.9127
# Epoch 199/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2410 - accuracy: 0.9099
# Epoch 200/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2708 - accuracy: 0.9017
# Epoch 201/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2238 - accuracy: 0.9179
# Epoch 202/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2188 - accuracy: 0.9187
# Epoch 203/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2310 - accuracy: 0.9141
# Epoch 204/400
# 50000/50000 [==============================] - 13s 256us/sample - loss: 0.2412 - accuracy: 0.9114
# Epoch 205/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2346 - accuracy: 0.9125
# Epoch 206/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2243 - accuracy: 0.9178
# Epoch 207/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2442 - accuracy: 0.9108
# Epoch 208/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2293 - accuracy: 0.9149
# Epoch 209/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2393 - accuracy: 0.9125
# Epoch 210/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2210 - accuracy: 0.9184
# Epoch 211/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2217 - accuracy: 0.9168
# Epoch 212/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2331 - accuracy: 0.9140
# Epoch 213/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2448 - accuracy: 0.9100
# Epoch 214/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2232 - accuracy: 0.9182
# Epoch 215/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2352 - accuracy: 0.9123
# Epoch 216/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2238 - accuracy: 0.9167
# Epoch 217/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2322 - accuracy: 0.9144
# Epoch 218/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2455 - accuracy: 0.9100
# Epoch 219/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2472 - accuracy: 0.9101
# Epoch 220/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2177 - accuracy: 0.9190
# Epoch 221/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2236 - accuracy: 0.9171
# Epoch 222/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2109 - accuracy: 0.9213
# Epoch 223/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2329 - accuracy: 0.9154
# Epoch 224/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2225 - accuracy: 0.9180
# Epoch 225/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2360 - accuracy: 0.9141
# Epoch 226/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2335 - accuracy: 0.9135
# Epoch 227/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2259 - accuracy: 0.9163
# Epoch 228/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2375 - accuracy: 0.9136
# Epoch 229/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2137 - accuracy: 0.9218
# Epoch 230/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2258 - accuracy: 0.9177
# Epoch 231/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2313 - accuracy: 0.9153
# Epoch 232/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2071 - accuracy: 0.9235
# Epoch 233/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2211 - accuracy: 0.9179
# Epoch 234/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2153 - accuracy: 0.9208
# Epoch 235/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2353 - accuracy: 0.9135
# Epoch 236/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2153 - accuracy: 0.9202
# Epoch 237/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2239 - accuracy: 0.9176
# Epoch 238/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2034 - accuracy: 0.9245
# Epoch 239/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2085 - accuracy: 0.9235
# Epoch 240/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2219 - accuracy: 0.9180
# Epoch 241/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2197 - accuracy: 0.9188
# Epoch 242/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2326 - accuracy: 0.9143
# Epoch 243/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2243 - accuracy: 0.9192
# Epoch 244/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2199 - accuracy: 0.9205
# Epoch 245/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2072 - accuracy: 0.9237
# Epoch 246/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2293 - accuracy: 0.9165
# Epoch 247/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2104 - accuracy: 0.9233
# Epoch 248/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2042 - accuracy: 0.9238
# Epoch 249/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2076 - accuracy: 0.9233
# Epoch 250/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2115 - accuracy: 0.9220
# Epoch 251/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2288 - accuracy: 0.9186
# Epoch 252/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2248 - accuracy: 0.9181
# Epoch 253/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2102 - accuracy: 0.9230
# Epoch 254/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2087 - accuracy: 0.9236
# Epoch 255/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2158 - accuracy: 0.9205
# Epoch 256/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2143 - accuracy: 0.9228
# Epoch 257/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2043 - accuracy: 0.9258
# Epoch 258/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2226 - accuracy: 0.9176
# Epoch 259/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2404 - accuracy: 0.9120
# Epoch 260/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2109 - accuracy: 0.9228
# Epoch 261/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2237 - accuracy: 0.9179
# Epoch 262/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2188 - accuracy: 0.9204
# Epoch 263/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2105 - accuracy: 0.9220
# Epoch 264/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2018 - accuracy: 0.9240
# Epoch 265/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2366 - accuracy: 0.9128
# Epoch 266/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2270 - accuracy: 0.9186
# Epoch 267/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1997 - accuracy: 0.9255
# Epoch 268/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2051 - accuracy: 0.9251
# Epoch 269/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1935 - accuracy: 0.9288
# Epoch 270/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2052 - accuracy: 0.9253
# Epoch 271/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2131 - accuracy: 0.9222
# Epoch 272/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2025 - accuracy: 0.9268
# Epoch 273/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2165 - accuracy: 0.9226
# Epoch 274/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2108 - accuracy: 0.9239
# Epoch 275/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1910 - accuracy: 0.9301
# Epoch 276/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1986 - accuracy: 0.9267
# Epoch 277/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2140 - accuracy: 0.9238
# Epoch 278/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2139 - accuracy: 0.9217
# Epoch 279/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2169 - accuracy: 0.9191
# Epoch 280/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2249 - accuracy: 0.9183
# Epoch 281/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2035 - accuracy: 0.9261
# Epoch 282/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2055 - accuracy: 0.9252
# Epoch 283/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2007 - accuracy: 0.9263
# Epoch 284/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2072 - accuracy: 0.9229
# Epoch 285/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2015 - accuracy: 0.9268
# Epoch 286/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1961 - accuracy: 0.9274
# Epoch 287/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1995 - accuracy: 0.9264
# Epoch 288/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2023 - accuracy: 0.9261
# Epoch 289/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1975 - accuracy: 0.9275
# Epoch 290/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2276 - accuracy: 0.9193
# Epoch 291/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2011 - accuracy: 0.9260
# Epoch 292/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2043 - accuracy: 0.9253
# Epoch 293/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1943 - accuracy: 0.9299
# Epoch 294/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2021 - accuracy: 0.9279
# Epoch 295/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2165 - accuracy: 0.9213
# Epoch 296/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2089 - accuracy: 0.9239
# Epoch 297/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2005 - accuracy: 0.9261
# Epoch 298/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.1996 - accuracy: 0.9277
# Epoch 299/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2045 - accuracy: 0.9259
# Epoch 300/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2008 - accuracy: 0.9263
# Epoch 301/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2035 - accuracy: 0.9267
# Epoch 302/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2010 - accuracy: 0.9265
# Epoch 303/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2239 - accuracy: 0.9192
# Epoch 304/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2008 - accuracy: 0.9264
# Epoch 305/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.1887 - accuracy: 0.9301
# Epoch 306/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2031 - accuracy: 0.9265
# Epoch 307/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.1936 - accuracy: 0.9299
# Epoch 308/400
# 50000/50000 [==============================] - 13s 252us/sample - loss: 0.2020 - accuracy: 0.9266
# Epoch 309/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1996 - accuracy: 0.9281
# Epoch 310/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1924 - accuracy: 0.9288
# Epoch 311/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1923 - accuracy: 0.9299
# Epoch 312/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2303 - accuracy: 0.9185
# Epoch 313/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2048 - accuracy: 0.9248
# Epoch 314/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1972 - accuracy: 0.9272
# Epoch 315/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2032 - accuracy: 0.9271
# Epoch 316/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1917 - accuracy: 0.9298
# Epoch 317/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2046 - accuracy: 0.9262
# Epoch 318/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2011 - accuracy: 0.9275
# Epoch 319/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1970 - accuracy: 0.9300
# Epoch 320/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1950 - accuracy: 0.9302
# Epoch 321/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2068 - accuracy: 0.9247
# Epoch 322/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1942 - accuracy: 0.9295
# Epoch 323/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.2025 - accuracy: 0.9266
# Epoch 324/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1935 - accuracy: 0.9287
# Epoch 325/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1967 - accuracy: 0.9300
# Epoch 326/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1910 - accuracy: 0.9309
# Epoch 327/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1948 - accuracy: 0.9285
# Epoch 328/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1957 - accuracy: 0.9287
# Epoch 329/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2081 - accuracy: 0.9257
# Epoch 330/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2113 - accuracy: 0.9223
# Epoch 331/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1806 - accuracy: 0.9351
# Epoch 332/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1876 - accuracy: 0.9308
# Epoch 333/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1914 - accuracy: 0.9298
# Epoch 334/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2196 - accuracy: 0.9222
# Epoch 335/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2144 - accuracy: 0.9215
# Epoch 336/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1819 - accuracy: 0.9329
# Epoch 337/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1819 - accuracy: 0.9356
# Epoch 338/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1996 - accuracy: 0.9264
# Epoch 339/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2028 - accuracy: 0.9256
# Epoch 340/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2062 - accuracy: 0.9243
# Epoch 341/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1827 - accuracy: 0.9338
# Epoch 342/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2099 - accuracy: 0.9265
# Epoch 343/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1823 - accuracy: 0.9336
# Epoch 344/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2012 - accuracy: 0.9288
# Epoch 345/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1802 - accuracy: 0.9345
# Epoch 346/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1776 - accuracy: 0.9349
# Epoch 347/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1877 - accuracy: 0.9326
# Epoch 348/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1846 - accuracy: 0.9325
# Epoch 349/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2098 - accuracy: 0.9248
# Epoch 350/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1883 - accuracy: 0.9317
# Epoch 351/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1824 - accuracy: 0.9337
# Epoch 352/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1964 - accuracy: 0.9276
# Epoch 353/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1746 - accuracy: 0.9371
# Epoch 354/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1999 - accuracy: 0.9276
# Epoch 355/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1961 - accuracy: 0.9298
# Epoch 356/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1803 - accuracy: 0.9348
# Epoch 357/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1898 - accuracy: 0.9320
# Epoch 358/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1888 - accuracy: 0.9321
# Epoch 359/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2028 - accuracy: 0.9272
# Epoch 360/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1875 - accuracy: 0.9315
# Epoch 361/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1858 - accuracy: 0.9319
# Epoch 362/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1931 - accuracy: 0.9312
# Epoch 363/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1928 - accuracy: 0.9304
# Epoch 364/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1878 - accuracy: 0.9307
# Epoch 365/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1829 - accuracy: 0.9346
# Epoch 366/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.1755 - accuracy: 0.9370
# Epoch 367/400
# 50000/50000 [==============================] - 13s 253us/sample - loss: 0.1812 - accuracy: 0.9345
# Epoch 368/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.2068 - accuracy: 0.9260
# Epoch 369/400
# 50000/50000 [==============================] - 13s 255us/sample - loss: 0.2156 - accuracy: 0.9238
# Epoch 370/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1941 - accuracy: 0.9301
# Epoch 371/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1753 - accuracy: 0.9354
# Epoch 372/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1820 - accuracy: 0.9335
# Epoch 373/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1946 - accuracy: 0.9289
# Epoch 374/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1983 - accuracy: 0.9292
# Epoch 375/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1832 - accuracy: 0.9346
# Epoch 376/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.1860 - accuracy: 0.9327
# Epoch 377/400
# 50000/50000 [==============================] - 13s 254us/sample - loss: 0.